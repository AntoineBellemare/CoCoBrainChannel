# %%
import pandas as pd
import scipy.io as sio
from scipy.io import savemat, loadmat
from EEG_pareidolia_utils import get_pareidolia_bids, reformat_events
from biotuner_utils import *
from biotuner_offline import *
from biotuner import *
import pyACA
import mne
from mne.datasets.brainstorm import bst_raw
from mne.time_frequency import tfr_morlet, psd_multitaper, psd_welch
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import scipy.io as sio

# %%
def computeFeatureCl(afAudioData, cFeatureName, f_s, bPlotOutput = False):

    # read audio file
    #[f_s, afAudioData] = ToolReadAudio(cPath)
    
    # for debugging
    #afAudioData = np.sin(2*np.pi * np.arange(f_s*1)*440./f_s)

    # compute feature
    [v, t] = pyACA.computeFeature(cFeatureName, afAudioData, f_s, None, 1024, 256)

    # plot feature output
    if bPlotOutput:
        plt.plot(t, v)

    return (v, t)

# %%
FOLDERPATH = r'E:\PhD\EEG_data\Pareidolia_BIDS'
FREQ_BANDS = [[1, 3], [3, 7], [7, 12], [12, 20],[20, 30], [30, 45], [45, 60]]
FREQ_NAMES = ['delta', 'theta', 'alpha', 'low-beta', 'high-beta', 'gamma1', 'gamma2']
RUN_LIST = {'pareidolia':['1', '2', '3', '4']}
SUBJ_LIST = ['01']
TASK_LIST = ['pareidolia']
frontal_L = ['E20', 'E21', 'E22', 'E23', 'E24', 'E26', 'E27', 'E12', 'E18', 'E19', 'E11', 'E15', 'E16']
frontal_R = ['E2', 'E3', 'E4', 'E5', 'E118', 'E124', 'E123', 'E9', 'E10', 'E14', 'E11', 'E15', 'E16']
frontal_LR = frontal_L+frontal_R
occi_R = ['E76', 'E83', 'E84']
occi_L = ['E66', 'E70', 'E71']

test_elec = ['E76']

# %%
epochs.ch_names

# %%
epochs = mne.read_epochs('../../pareidolia_run2.fif')
epochs = epochs.apply_baseline((-1.5, -0.1))
epochs = epochs.crop(0.5, 7.5)
epochs_data = epochs.get_data()

# %%
par = ['Image_on_par_high', 'Image_on_par_mid', 'Image_on_par_low']
nopar = ['Image_on_nopar_high', 'Image_on_nopar_mid', 'Image_on_nopar_low']
condition = par
chs = frontal_LR

# %%
eeg_data = epochs[condition].average(chs)
eeg_data = np.average(eeg_data.data, axis = 0)
eeg_data = np.interp(eeg_data, (eeg_data.min(), eeg_data.max()), (-1, +1))
eeg_data

# %% [markdown]
# ## Empirical Mode Decomposition

# %%
from PyEMD import EMD, EEMD
import numpy as np
s = np.interp(eeg_data, (eeg_data.min(), eeg_data.max()), (0, +1))
eemd = EEMD()
#s = np.random.random(1001)

S = s
t = np.linspace(0, 1, 7001)
# Say we want detect extrema using parabolic method
import time
start = time.time()
emd = eemd.EMD
emd.extrema_detection="parabol"
eIMFs = EMD().emd(s,t)
#eIMFs = eemd.eemd(S, t)
nIMFs = eIMFs.shape[0]
stop = time.time()
print(stop-start)
plt.figure(figsize=(12,9))
plt.subplot(nIMFs+1, 1, 1)
plt.plot(t, S, 'r')

for n in range(nIMFs):
    plt.subplot(nIMFs+1, 1, n+2)
    plt.plot(t, eIMFs[n], 'g')
    plt.ylabel("eIMF %i" %(n+1))
    plt.locator_params(axis='y', nbins=5)

plt.xlabel("Time [s]")
plt.tight_layout()
#plt.savefig('eemd_example', dpi=120)
plt.show()
# Out:
# 0.8020641803741455

# %% [markdown]
# ## Plot of spectral features across EMDs

# %%
df = pd.DataFrame()
i = 0
for e in eIMFs:
    eeg_data = np.interp(eeg_data, (eeg_data.min(), eeg_data.max()), (-1, +1))
    i +=1
    [f,t] = computeFeatureCl(e, "SpectralCentroid", 1000)
    [f,t] = pyACA.computePitch('TimeAcf', e, 1000, afWindow=None, iBlockLength=1000, iHopLength=200)
    df[i] = np.squeeze(f)

# %%
import seaborn as sbn
ax = sbn.lineplot(data=df.loc[5:20, 2:6], dashes = False)
ax.set(xlabel='Time', ylabel='Spectral Centroid')
ax.set_yscale('log')
plt.legend(scatterpoints=1, frameon=True, labelspacing=1, title='EMDs', loc = 'best')
colors = ['black','black','black','black','black','black','black','black','black','black']
for xc,c, l in zip(xposition,colors, labels):
    plt.axvline(x=xc, label='{} = {}'.format(l, xc), c=c, linestyle = 'dotted')
#plt.savefig('EMDs_spectral_flux_par_frontalR_1-5', dpi=120)

# %%
xposition
# Out:
# [5, 6, 7, 8, 9, 12, 15]

# %%
eIMFs_new = eIMFs[1:6]
df = pd.DataFrame()
i = 0
for e in eIMFs_new:
    i +=1
    #[f,t] = computeFeatureCl(e, "SpectralCentroid", 1000)
    [f,t] = pyACA.computePitch('TimeAcf', e, 1000, afWindow=None, iBlockLength=1000, iHopLength=200)
    df[i] = np.squeeze(f)

peaks_t = []
peaks_list = []
for t in range(len(df)):
    imf_temp = []
    for imf in range(df.shape[1]):
        imf = imf+1
        imf_temp.append(df.loc[t, imf])
    peaks_list.append(imf_temp) 
peaks_total = np.array(peaks_list) 

cons_tot = []
peaks_cons_temp = []
for peaks in peaks_total[1:20]:
    cons, peaks_cons = compute_consonance(peaks, 0.1)
    peaks_cons_temp.append(peaks_cons)

xposition = []
for i in range(len(peaks_cons_temp)):
    if len(peaks_cons_temp[i]) != 0:
        xposition.append(i)
# Out:
# [5, 6, 7, 8, 9, 12, 15]

# %%
#peaks_cons_tot = np.array(peaks_cons_temp)

# %%
for i in range(len(peaks_cons_temp)):
    if len(peaks_cons_temp[i]) != 0:
        print('consonance')
        print(i)
# Out:
# consonance
# 5
# consonance
# 6
# consonance
# 7
# consonance
# 8
# consonance
# 9
# consonance
# 12
# consonance
# 15

# %%
EMD_spectromorph_graph(path)
# Out:
# Reading ../../pareidolia_run2.fif ...
# <ipython-input-322-0360a00a2684>:3: RuntimeWarning: This filename (../../pareidolia_run2.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path)
#     Found the data of interest:
#         t =   -1500.00 ...    8000.00 ms
#         0 CTF compensation matrices available
# 104 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Applying baseline correction (mode: mean)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-323-e72373175a3f> in <module>
# ----> 1 EMD_spectromorph_graph(path)
#
# <ipython-input-322-0360a00a2684> in EMD_spectromorph_graph(path)
#      58
#      59
# ---> 60             plt.savefig('Spectromorph_EMD_multi_{}_cond-{}'.format(plot_type, ch, condition), dpi=120)
#      61             plt.clf()
#      62     return percentage_fit
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1087         minor_locs = self.get_minorticklocs()
#    1088         minor_labels = self.minor.formatter.format_ticks(minor_locs)
# -> 1089         minor_ticks = self.get_minor_ticks(len(minor_locs))
#    1090         self.minor.formatter.set_locs(minor_locs)
#    1091         for tick, loc, label in zip(minor_ticks, minor_locs, minor_labels):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_minor_ticks(self, numticks)
#    1426             self.minorTicks.append(tick)
#    1427             tick.gridline.set_visible(self._gridOnMinor)
# -> 1428             self._copy_tick_props(self.minorTicks[0], tick)
#    1429
#    1430         return self.minorTicks[:numticks]
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1379         dest.label2.update_from(src.label2)
#    1380         dest.tick1line.update_from(src.tick1line)
# -> 1381         dest.tick2line.update_from(src.tick2line)
#    1382         dest.gridline.update_from(src.gridline)
#    1383
#
# ~\Anaconda3\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1347         self._linestyle = other._linestyle
#    1348         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1349                                    other._marker.get_fillstyle())
#    1350         self._drawstyle = other._drawstyle
#    1351
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickright(self)
#     753
#     754     def _set_tickright(self):
# --> 755         self._transform = Affine2D().scale(1.0, 1.0)
#     756         self._snap_threshold = 1.0
#     757         self._filled = False
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# KeyboardInterrupt:

# %%
##Compare n of consonance between EEG and white noise

def EMD_spectromorph_graph(path):
    
    epochs = mne.read_epochs(path)
    epochs = epochs.apply_baseline((-1.5, -0.1))
    epochs = epochs.crop(0.5, 7.5)
    channels = epochs.ch_names
    for condition in conditions:
        i = 0
        for ch in channels: 
            eeg_data = epochs[condition].average(ch)
            eeg_data = np.average(eeg_data.data, axis = 0)
            s = np.interp(eeg_data, (eeg_data.min(), eeg_data.max()), (0, +1))
            eemd = EEMD()
            S = s
            t = np.linspace(0, 1, 7001)
            # Say we want detect extrema using parabolic method
            emd = eemd.EMD
            emd.extrema_detection="parabol"
            eIMFs = EMD().emd(s,t)
            eIMFs = np.flip(eIMFs, axis =0)
            
            eIMFs = eIMFs[1:6]
            df = pd.DataFrame()
            i = 0
            for e in eIMFs:
                i +=1
                #[f,t] = computeFeatureCl(e, "SpectralCentroid", 1000)
                [f,t] = pyACA.computePitch('TimeAcf', e, 1000, afWindow=None, iBlockLength=1000, iHopLength=200)
                df[i] = np.squeeze(f)
            peaks_t = []
            peaks_list = []
            for t in range(len(df)):
                imf_temp = []
                for imf in range(df.shape[1]):
                    imf = imf+1
                    imf_temp.append(df.loc[t, imf])
                peaks_list.append(imf_temp) 
            peaks_total = np.array(peaks_list) 

            cons_tot = []
            peaks_cons_temp = []
            for peaks in peaks_total[1:20]:
                cons, peaks_cons = compute_consonance(peaks, 0.1)
                peaks_cons_temp.append(peaks_cons)

            xposition = []
            for i in range(len(peaks_cons_temp)):
                if len(peaks_cons_temp[i]) != 0:
                    xposition.append(i)
                    n = n+1
            ax = sbn.lineplot(data=df.loc[0:20, 0:5], dashes = False)
            ax.set(xlabel='Time', ylabel='TimeAcf')
            ax.set_yscale('log')
            plt.legend(scatterpoints=1, frameon=True, labelspacing=1, title='EMDs', loc = 'best')
            colors = ['black','black','black','black','black','black','black','black','black','black']
            for xc,c, l in zip(xposition,colors, labels):
                plt.axvline(x=xc, label='{} = {}'.format(l, xc), c=c, linestyle = 'dotted')
            
            
            plt.savefig('Spectromorph_EMD_multi_{}_cond-{}'.format(plot_type, ch, condition), dpi=120)
            plt.clf()
    return n

# %%
a= pyACA.computeKey(eeg_data,  1000)
a

# %%
[T,beats] = pyACA.computeBeatHisto(eeg_data, 1000)
plt.plot(T,np.squeeze(beats))

# %%
[f,t] = computeFeatureCl(eIMFs[3], "SpectralSlope", 1024)
pitch_chroma = pd.DataFrame(f)
pitch_chroma

# %%
##Plot of pitch tracking across EMDs###
df = pd.DataFrame()
i = 0
for e in eIMFs:
    i +=1
    [f, t] = pyACA.computePitch('TimeAcf', e, 1000, afWindow=None, iBlockLength=1000, iHopLength=200)
    df[i] = f

# %%
import seaborn as sbn
ax = sbn.lineplot(data=df.loc[0:13, 3:6], dashes = False)
ax.set(xlabel='Time', ylabel='Pitch (SpectralAcf)')
ax.set_yscale('log')
plt.legend(scatterpoints=1, frameon=True, labelspacing=1, title='EMDs', loc = 'lower left')
#plt.savefig('EMDs_pitch_par_frontalR', dpi=120)

# %%
array = ((np.array(df)).T)*100
array[4]

# %%
###PLAY AUDIO#####

import math

from pyaudio import PyAudio # sudo apt-get install python{,3}-pyaudio

try:
    from itertools import izip
except ImportError: # Python 3
    izip = zip
    xrange = range

def sine_tone(frequency, duration, volume=1, sample_rate=44100):
    n_samples = int(sample_rate * duration)
    restframes = n_samples % sample_rate

    p = PyAudio()
    stream = p.open(format=p.get_format_from_width(1), # 8bit
                    channels=1, # mono
                    rate=sample_rate,
                    output=True)
    s = lambda t: volume * math.sin(2 * math.pi * frequency * t / sample_rate)
    samples = (int(s(t) * 0x7f + 0x80) for t in xrange(n_samples))
    for buf in izip(*[samples]*sample_rate): # write several samples at a time
        stream.write(bytes(bytearray(buf)))

    # fill remainder of frameset with silence
    stream.write(b'\x80' * restframes)

    stream.stop_stream()
    stream.close()
    p.terminate()

# %%
for i in range(len(array[3])):
    print(array[3][i])
    sine_tone(array[3][i], 0.2, volume=0.5)
    
    #sine_tone(array[4][i], 0.2, volume=0.5)

# %%
sine_tone(300, 0.5, volume=1)

# %%
import operator
import scipy
peaks_EMD = []
for e in range(len(eIMFs[1 :-1])):
    freqs, psd = scipy.signal.welch(eIMFs[e], 1000, nfft = 4096, nperseg = 1024)
    index, value = max(enumerate(psd), key=operator.itemgetter(1))
    peaks_EMD.append(freqs[index])
    
peaks_EMD = np.round(peaks_EMD[1:-1], 1)

# %%
peaks_EMD
# Out:
# array([49.8, 18.6,  8.5,  5.6,  2. ])

# %%
import scipy.signal
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import StrMethodFormatter
##plot PowerSpectralPlot of each EMD##
freqs, psd = scipy.signal.welch(eIMFs[3], 1000, nfft = 4096, nperseg = 512)
freqs2, psd2 = scipy.signal.welch(eIMFs[2], 1000, nfft = 4096, nperseg = 512)

plt.figure(figsize=(5, 4))
plt.plot(freqs, psd)
plt.plot(freqs, psd2)

plt.xlim([1, 60])
#plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.4f}'))
plt.title('PSD of Empirical Mode Decomposition 1')
plt.xlabel('Frequency')
plt.ylabel('Power')
plt.xscale('log')
plt.tight_layout()
#plt.savefig('PSD_EMD_5_delta', dpi=120)

# %%
path = '../../pareidolia_run2.fif'
epochs = mne.read_epochs(path)
epochs2 = epochs.copy().apply_baseline((-1.5, -0.1))
epochs2 = epochs2.crop(0.5, 7.5)
# Out:
# Reading ../../pareidolia_run2.fif ...
# <ipython-input-4-ea59acbb798d>:2: RuntimeWarning: This filename (../../pareidolia_run2.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path)
#     Found the data of interest:
#         t =   -1500.00 ...    8000.00 ms
#         0 CTF compensation matrices available
# 104 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Applying baseline correction (mode: mean)

# %%
par = ['Image_on_par_high', 'Image_on_par_mid', 'Image_on_par_low']
nopar = ['Image_on_nopar_high', 'Image_on_nopar_mid', 'Image_on_nopar_low']
condition = nopar
ch = 'E81'
dim_reduc = 'avg' #Mode could either be 'avg' or 'mode'
precision = 0.25   #Default precision is 0.125Hz
FREQ_BANDS = [[1, 3], [3, 7], [7, 12], [12, 30],[30, 70]]
peaks= compute_peaks_avg(epochs.copy(), condition, ch, FREQ_BANDS, dim_reduc = dim_reduc, tmin = 0.5, tmax = 7.5, precision = precision, sf =1000)
peaks
# Out:
# Applying baseline correction (mode: mean)
# (104, 114, 7001)
# 7000
# Effective window size : 4.000 (s)
# 2
# Effective window size : 4.000 (s)
# 14
# Effective window size : 4.000 (s)
# 0
# Effective window size : 4.000 (s)
# 61
# Effective window size : 4.000 (s)
# 79
# array([ 1.5,  6.5,  7. , 27.2, 49.8])

# %%
eeg_data = epochs2[condition].average(ch)
eeg_data = np.average(eeg_data.data, axis = 0)

# %%
import scipy
psd_all = []
freqs_all = []
FREQs_temp=[]
for minf, maxf in FREQ_BANDS:
    freqs, psd = scipy.signal.welch(eeg_data, 1000, nfft = 4096, nperseg = 1024)
    psd = 10. * np.log10(psd) 
    bin_size = 500/len(freqs)
    min_index = int(minf/bin_size)+2
    max_index = int(maxf/bin_size)+2
    index_max = np.argmax(np.array(psd[min_index:max_index]))
    print(index_max)
    freq = freqs[min_index+index_max]
     #   print(index_max) # Should not be zero in all bands (would signify strong 1/f trend)
    FREQs_temp.append(freq)
    
FREQS = np.array(FREQs_temp)
# Out:
# 0
# 13
# 9
# 20
# 1

# %%
FREQS
# Out:
# array([ 1.46484375,  6.59179688,  9.52148438, 17.33398438, 30.51757812])

# %%
plt.plot(freqs[0:120], psd[0:120])

# %%
minf

# %%
##Multiple PSD##
from PyEMD import EMD, EEMD
import numpy as np
import operator
import scipy
par = ['Image_on_par_high', 'Image_on_par_mid', 'Image_on_par_low']
nopar = ['Image_on_nopar_high', 'Image_on_nopar_mid', 'Image_on_nopar_low']
conditions = [par, nopar]
path = '../../pareidolia_run2.fif'


def EMD_PSD_graph(path, bands = 0, xmin=1, xmax=70, plot_type = 'stackplot', compare = True):
    
    
    if bands == 0:
        bands = [[0, 3], [3, 7], [7, 12], [12, 30], [30, 70]]
    
    epochs = mne.read_epochs(path)
    epochs = epochs.apply_baseline((-1.5, -0.1))
    epochs = epochs.crop(0.5, 7.5)
    channels = epochs.ch_names
    percentage_fit = []
    for condition in conditions:
        i = 0
        for ch in channels: 
            eeg_data = epochs[condition].average(ch)
            eeg_data = np.average(eeg_data.data, axis = 0)
            s = np.interp(eeg_data, (eeg_data.min(), eeg_data.max()), (0, +1))
            eemd = EEMD()
            S = s
            t = np.linspace(0, 1, 7001)
            # Say we want detect extrema using parabolic method
            emd = eemd.EMD
            emd.extrema_detection="parabol"
            eIMFs = EMD().emd(s,t)
            eIMFs = np.flip(eIMFs, axis =0)
            peaks_EMD = []
            for e in range(len(eIMFs[:])):
                freqs, psd = scipy.signal.welch(eIMFs[e], 1000, nfft = 4096, nperseg = 1024)
                index, value = max(enumerate(psd), key=operator.itemgetter(1))
                peaks_EMD.append(freqs[index])
            peaks_EMD = np.round(peaks_EMD[:], 1)

            print(peaks_EMD)

            for e, p in enumerate(peaks_EMD):
                if p > 3 and p<7 and peaks_EMD[e-1]<3:
                    index_start = e-1
            if peaks_EMD[index_start+4]<30:
                index_start = index_start +1
            if peaks_EMD[index_start+4]>90:
                index_start = index_start-1
            peaks_EMD = peaks_EMD[index_start:index_start+5]
            eIMFs = eIMFs[index_start:index_start+5]
            freqs_all = []
            psd_all = []
            for e in range(len(eIMFs)):
                freqs, psd = scipy.signal.welch(eIMFs[e], 1000, nfft = 4096, nperseg = 1024)
                freqs_all.append(freqs)
                psd_all.append(psd)
            freqs_all = np.array(freqs_all)
            psd_all = np.array(psd_all)
            # Stackplot with X, Y, colors value 
            
            
            if plot_type == 'line':
                color_line = ['aqua', 'darkturquoise', 'darkcyan', 'darkslategrey', 'black']
                plt.plot(freqs, psd_all[0], color = color_line[0])
                plt.plot(freqs, psd_all[1], color = color_line[1])
                plt.plot(freqs, psd_all[2], color = color_line[2])
                plt.plot(freqs, psd_all[3], color = color_line[3])
                plt.plot(freqs, psd_all[4], color = color_line[4])
                color1 = 'midnightblue'
                color2 = 'turquoise'
                colors = ['darkgoldenrod', 'goldenrod', 'orange', 'gold', 'khaki']
                color_bg = ['darkgoldenrod', 'goldenrod', 'orange', 'gold', 'khaki']
                #color_bg = ['paleturquoise', 'aqua', 'darkturquoise','darkcyan' , 'darkslategrey']
                alpha = [0.6, 0.63, 0.66, 0.69, 0.72]
                shadow=0.9
                if compare==True:
                    freqs_full, psd_full = scipy.signal.welch(eeg_data, 1000, nfft = 4096, nperseg = 1024)
                    psd_full = np.interp(psd_full, (psd_full.min(), psd_full.max()), (0, 0.005))
                    plt.plot(freqs, psd_full, color = 'deeppink', linestyle='dashed')
                plt.text(1.7, 0.0028, 'delta', horizontalalignment = 'center')
                plt.text(4.5, 0.0028, 'theta', horizontalalignment = 'center')
                plt.text(9, 0.0028, 'alpha', horizontalalignment = 'center')
                plt.text(19, 0.0028, 'beta', horizontalalignment = 'center')
                plt.text(47, 0.0028, 'gamma', horizontalalignment = 'center')
            if plot_type == 'stackplot':
                pal = sbn.color_palette("YlOrBr")
                plt.stackplot(freqs, psd_all[0], psd_all[1],psd_all[2], psd_all[3], psd_all[4],
                          colors =pal)
                colors = ['darkslategrey', 'darkcyan', 'darkturquoise', 'aqua', 'paleturquoise']
                color_bg = ['navy', 'darkred', 'navy', 'darkred', 'navy']
                alpha = [0.2, 0.35, 0.5, 0.65, 0.80]
                shadow = 0.9
            plt.xlim([xmin, xmax])
            plt.ylim([0.000001, 0.005])
            #plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.4f}'))
            plt.title('PSD of Empirical Mode Decomposition 1 to 5; ch:{}'.format(ch))
            plt.xlabel('Frequency')
            plt.ylabel('Power')
            plt.yscale('log')
            plt.xscale('log')

            xposition = peaks_EMD

            labels = ['EMD1', 'EMD2', 'EMD3', 'EMD4', 'EMD5']
            for p, n, band in zip(peaks_EMD, range(len(labels)), bands):
                print(band[0])
                print(band[1])
                print(p)
                
                if p > band[0] and p<= band[1]:
                    print('got it')
                    labels[n] = labels[n]+'*'
                    i = i+1
            
            print(labels)
            for xc,c, l in zip(xposition,color_line, labels):
                plt.axvline(x=xc, label='{} = {}'.format(l, xc), c=c)
            plt.axvspan(0, 3, ymin = shadow, alpha=alpha[0], color=color_bg[0], ec ='black')
            plt.axvspan(3, 7, ymin = shadow, alpha=alpha[1], color=color_bg[1],ec ='black')
            plt.axvspan(7, 12, ymin = shadow, alpha=alpha[2], color=color_bg[2], ec ='black')
            plt.axvspan(12, 30, ymin = shadow, alpha=alpha[3], color=color_bg[3], ec ='black')
            plt.axvspan(30, 70, ymin = shadow, alpha=alpha[4], color=color_bg[4], ec ='black')
            
            plt.legend(loc='lower left')
            #plt.show()

            #plt.tight_layout()

            plt.savefig('PSD_EMD_multi_{}_{}_cond-{}'.format(plot_type, ch, condition), dpi=120)
            plt.clf()
        percentage_fit.append((i/(len(epochs.ch_names)*5))*100)
    percentage_fit = np.array(percentage_fit)
    return percentage_fit

# %%
epochs = mne.read_epochs(path)
epochs = epochs.apply_baseline((-1.5, -0.1))
epochs = epochs.crop(0.5, 7.5)

# %%
from PyEMD import EMD, EEMD
import numpy as np
import operator
import scipy


plot_type = 'line'
xmin=1
xmax=70
bands = [[0, 3], [3, 7], [7, 12], [12, 30], [30, 70]]
compare=True
ch = frontal_L


eeg_data = epochs2[condition].average(ch)
eeg_data = np.average(eeg_data.data, axis = 0)
print(eeg_data.shape)
s = np.interp(eeg_data, (eeg_data.min(), eeg_data.max()), (0, +1))
eemd = EEMD()
S = s
t = np.linspace(0, 1, 7001)
# Say we want detect extrema using parabolic method
emd = eemd.EMD
emd.extrema_detection="parabol"
eIMFs = EMD().emd(s,t)
eIMFs = np.flip(eIMFs, axis =0)
peaks_EMD = []
for e in range(len(eIMFs[:])):
    freqs, psd = scipy.signal.welch(eIMFs[e], 1000, nfft = 4096, nperseg = 1024)
    index, value = max(enumerate(psd), key=operator.itemgetter(1))
    peaks_EMD.append(freqs[index])
peaks_EMD = np.round(peaks_EMD[:], 1)

print(peaks_EMD)

for e, p in enumerate(peaks_EMD):
    if p > 3 and p<7 and peaks_EMD[e-1]<3:
        index_start = e-1
if peaks_EMD[index_start+4]<30:
    index_start = index_start +1
if peaks_EMD[index_start+4]>90:
    index_start = index_start-1
peaks_EMD = peaks_EMD[index_start:index_start+5]
eIMFs = eIMFs[index_start:index_start+5]
freqs_all = []
psd_all = []
for e in range(len(eIMFs)):
    freqs, psd = scipy.signal.welch(eIMFs[e], 1000, nfft = 4096, nperseg = 1024)
    freqs_all.append(freqs)
    psd_all.append(psd)
freqs_all = np.array(freqs_all)
psd_all = np.array(psd_all)
# Stackplot with X, Y, colors value 


if plot_type == 'line':
    plt.plot(freqs, psd_all[0], color = 'aqua')
    plt.plot(freqs, psd_all[1], color = 'darkturquoise')
    plt.plot(freqs, psd_all[2], color = 'darkcyan')
    plt.plot(freqs, psd_all[3], color = 'darkslategrey')
    plt.plot(freqs, psd_all[4], color = 'black')
    
    if compare==True:
        freqs_full, psd_full = scipy.signal.welch(eeg_data, 1000, nfft = 4096, nperseg = 1024)
        psd_full = np.interp(psd_full, (psd_full.min(), psd_full.max()), (0, 0.005))
        plt.plot(freqs, psd_full, color = 'magenta', linestyle='dashed')
        
    
    color1 = 'turquoise'
    color2 = 'indigo'
    colors = ['darkgoldenrod', 'goldenrod', 'orange', 'gold', 'khaki']
    color_bg = ['paleturquoise', 'aqua', 'darkturquoise','darkcyan' , 'darkslategrey']
    alpha = [0.3, 0.4, 0.5, 0.6, 0.7]
    shadow=0.9
if plot_type == 'stackplot':
    pal = sbn.color_palette("YlOrBr")
    plt.stackplot(freqs, psd_all[0], psd_all[1],psd_all[2], psd_all[3], psd_all[4],
              colors =pal)
    colors = ['darkslategrey', 'darkcyan', 'darkturquoise', 'aqua', 'paleturquoise']
    color_bg = ['navy', 'darkred', 'navy', 'darkred', 'navy']
    alpha = [0.2, 0.35, 0.5, 0.65, 0.80]
    shadow = 0.9
plt.xlim([xmin, xmax])
plt.ylim([0.000001, 0.005])
#plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.4f}'))
plt.title('PSD of Empirical Mode Decomposition 1 to 5; ch:{}'.format(ch))
plt.xlabel('Frequency')
plt.ylabel('Power')
plt.yscale('log')
plt.xscale('log')

xposition = peaks_EMD

labels = ['EMD1', 'EMD2', 'EMD3', 'EMD4', 'EMD5']
for p, n, band in zip(peaks_EMD, range(len(labels)), bands):
    #print(band[0])
    #print(band[1])
    #print(p)

    if p > band[0] and p<= band[1]:
        #print('got it')
        labels[n] = labels[n]+'*'
        #i = i+1

print(labels)
for xc,c, l in zip(xposition,colors, labels):
    plt.axvline(x=xc, label='{} = {}'.format(l, xc), c=c)
plt.axvspan(0, 3, ymin = shadow, alpha=alpha[0], color=color_bg[0], ec ='black')
plt.text(1.7, 0.0028, 'delta', horizontalalignment = 'center')
plt.text(4.5, 0.0028, 'theta', horizontalalignment = 'center')
plt.text(9, 0.0028, 'alpha', horizontalalignment = 'center')
plt.text(19, 0.0028, 'beta', horizontalalignment = 'center')
plt.text(47, 0.0028, 'gamma', horizontalalignment = 'center')
plt.axvspan(3, 7, ymin = shadow, alpha=alpha[1], color=color_bg[1],ec ='black')
plt.axvspan(7, 12, ymin = shadow, alpha=alpha[2], color=color_bg[2], ec ='black')
plt.axvspan(12, 30, ymin = shadow, alpha=alpha[3], color=color_bg[3], ec ='black')
plt.axvspan(30, 70, ymin = shadow, alpha=alpha[4], color=color_bg[4], ec ='black')
plt.legend(loc='lower left')
plt.show()

#plt.tight_layout()

#plt.savefig('PSD_EMD_multi_{}_{}_cond-{}'.format(plot_type, ch, condition), dpi=120)
# Out:
# (7001,)
# [  1.    1.    1.    2.    5.6   8.5  18.6  49.8 112.8]
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']

# %%
scores = EMD_PSD_graph(path, plot_type = 'line')
# Out:
# Reading ../../pareidolia_run2.fif ...
# <ipython-input-350-990204f31677>:18: RuntimeWarning: This filename (../../pareidolia_run2.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs = mne.read_epochs(path)
#     Found the data of interest:
#         t =   -1500.00 ...    8000.00 ms
#         0 CTF compensation matrices available
# 104 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Applying baseline correction (mode: mean)
# [  1.    1.    1.    2.    3.7   8.5  30.   48.8 153.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 30.0
# got it
# 30
# 70
# 48.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.9   6.6  14.6  25.9  47.9 109.6]
# 0
# 3
# 2.9
# got it
# 3
# 7
# 6.6
# got it
# 7
# 12
# 14.6
# 12
# 30
# 25.9
# got it
# 30
# 70
# 47.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    4.4   6.8  23.4  43.5 110.4]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 4.4
# got it
# 7
# 12
# 6.8
# 12
# 30
# 23.4
# got it
# 30
# 70
# 43.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   4.9   5.6  19.3  35.9 109.1]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 5.6
# 12
# 30
# 19.3
# got it
# 30
# 70
# 35.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   5.1   6.1  22.2  35.6 122.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 6.1
# 12
# 30
# 22.2
# got it
# 30
# 70
# 35.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.7   4.9   6.8  12.9  29.5 153.6]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 6.8
# 12
# 30
# 12.9
# got it
# 30
# 70
# 29.5
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [ 1.   1.   1.   1.   2.   5.1 11.5 23.4 44.4 94.2]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 11.5
# got it
# 12
# 30
# 23.4
# got it
# 30
# 70
# 44.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    6.1  11.   31.2  39.8 109.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 11.0
# got it
# 12
# 30
# 31.2
# 30
# 70
# 39.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.    6.1   7.1  27.3  40.8 109.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 7.1
# got it
# 12
# 30
# 27.3
# got it
# 30
# 70
# 40.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   2.7   5.4  12.5  35.6 109.9]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 2.7
# 7
# 12
# 5.4
# 12
# 30
# 12.5
# got it
# 30
# 70
# 35.6
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.9   4.9   5.1  23.7  27.8 109.9]
# 0
# 3
# 2.9
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 5.1
# 12
# 30
# 23.7
# got it
# 30
# 70
# 27.8
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [ 1.   1.   1.2  6.3 17.1 31.2 37.4 72.5]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 17.1
# 12
# 30
# 31.2
# 30
# 70
# 37.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.2   6.6   8.3  34.9  65.2 112.5]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.6
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 34.9
# 30
# 70
# 65.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [ 1.   1.   1.   2.   6.1  5.9 26.6 53.  95.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 5.9
# 12
# 30
# 26.6
# got it
# 30
# 70
# 53.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   3.7   8.5  31.5  52.5 105.7]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 31.5
# 30
# 70
# 52.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.    6.8  11.   26.4  50.  112.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.8
# got it
# 7
# 12
# 11.0
# got it
# 12
# 30
# 26.4
# got it
# 30
# 70
# 50.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    2.    4.9   6.6  30.8  46.9 113.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 6.6
# 12
# 30
# 30.8
# 30
# 70
# 46.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.    2.9   6.6  16.6  54.4 109.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 2.9
# 7
# 12
# 6.6
# 12
# 30
# 16.6
# got it
# 30
# 70
# 54.4
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    8.1  17.8  28.6  51.3 105.2]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 8.1
# 7
# 12
# 17.8
# 12
# 30
# 28.6
# got it
# 30
# 70
# 51.3
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   2.   5.9 11.7 23.9 50.5 94.2]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 11.7
# got it
# 12
# 30
# 23.9
# got it
# 30
# 70
# 50.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   2.7  6.1 12.7 20.  50.5 96.4]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 12.7
# 12
# 30
# 20.0
# got it
# 30
# 70
# 50.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.7   6.8   8.8  21.7  62.  113.8]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 6.8
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 21.7
# got it
# 30
# 70
# 62.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.4   8.1  23.9  43.7 154.8]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 23.9
# got it
# 30
# 70
# 43.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   5.9   8.1  24.2  54.4 153.6]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 24.2
# got it
# 30
# 70
# 54.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.5   5.9   7.8  26.9  54.4 153.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 26.9
# got it
# 30
# 70
# 54.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.4   7.8  16.6  64.2 121.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 16.6
# got it
# 30
# 70
# 64.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   5.4   8.1  21.7  54.2 121.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 21.7
# got it
# 30
# 70
# 54.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   5.1   8.1  17.3  24.4 121.6]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 17.3
# got it
# 30
# 70
# 24.4
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    3.2   5.4   8.1  26.4  54.9 142.8]
# 0
# 3
# 3.2
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 26.4
# got it
# 30
# 70
# 54.9
# got it
# ['EMD1', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   3.7   8.1  23.9  66.2 146.2]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 23.9
# got it
# 30
# 70
# 66.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   6.1   8.3  21.7  64.2 133.1]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 21.7
# got it
# 30
# 70
# 64.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   3.2   8.1  21.7  64.  121.8]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 21.7
# got it
# 30
# 70
# 64.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   4.2   8.1  21.2  22.2 121.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 21.2
# got it
# 30
# 70
# 22.2
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    2.    7.8   8.5  26.9  62.7 105.2]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 7.8
# 7
# 12
# 8.5
# got it
# 12
# 30
# 26.9
# got it
# 30
# 70
# 62.7
# got it
# ['EMD1*', 'EMD2', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.2   1.2   5.4   8.1  25.4  43.7 147.5]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 25.4
# got it
# 30
# 70
# 43.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   6.1   8.3  21.7  54.9 138.4]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 21.7
# got it
# 30
# 70
# 54.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   3.2   7.6   8.3  26.1  68.4 121.8]
# 0
# 3
# 3.2
# 3
# 7
# 7.6
# 7
# 12
# 8.3
# got it
# 12
# 30
# 26.1
# got it
# 30
# 70
# 68.4
# got it
# ['EMD1', 'EMD2', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   3.7   8.3  21.2  23.9 121.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 21.2
# got it
# 30
# 70
# 23.9
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   5.1   8.3  23.4  62.7 151.4]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 23.4
# got it
# 30
# 70
# 62.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   3.7   8.1  16.4  40.  105.2]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 16.4
# got it
# 30
# 70
# 40.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   3.9   8.3  17.3  54.7 155. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 17.3
# got it
# 30
# 70
# 54.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    3.4   8.1  15.4  71.8 155. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 71.8
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.7   3.9   8.1  15.4  54.9 116.2]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 54.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   4.2   8.1  15.1  21.2 121.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.1
# got it
# 30
# 70
# 21.2
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   3.9   8.3  15.1  24.4 121.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 15.1
# got it
# 30
# 70
# 24.4
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.7   3.4   8.1  15.4  21.  121.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 21.0
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    1.7   3.4   8.1  12.9  21.5 121.6]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 12.9
# got it
# 30
# 70
# 21.5
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   2.9   5.4  15.4  38.3 140.1]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 2.9
# 7
# 12
# 5.4
# 12
# 30
# 15.4
# got it
# 30
# 70
# 38.3
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   2.    6.1  11.2  20.3  40.8 140.4]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 11.2
# got it
# 12
# 30
# 20.3
# got it
# 30
# 70
# 40.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    0.7   2.    3.7   8.3  23.7  40.3 130.4]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 23.7
# got it
# 30
# 70
# 40.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   3.9   7.8  15.1  31.  125. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 15.1
# got it
# 30
# 70
# 31.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   4.2   8.1  14.9  54.9 116.2]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 14.9
# got it
# 30
# 70
# 54.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   4.2   8.1  15.4  26.9 110.8]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 26.9
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   3.4   7.8  15.4  21.2 121.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 21.2
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    3.7   7.3  15.6  24.7 139.9]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 7.3
# got it
# 12
# 30
# 15.6
# got it
# 30
# 70
# 24.7
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    1.7   3.2   7.3  24.7  55.4 125. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 7.3
# got it
# 12
# 30
# 24.7
# got it
# 30
# 70
# 55.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.5   4.2   8.1  16.4  56.4 125. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 16.4
# got it
# 30
# 70
# 56.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   6.1   7.8  15.1  33.  125. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 15.1
# got it
# 30
# 70
# 33.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.5   3.7   7.3  15.4  54.7 110.6]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 7.3
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 54.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    5.6  12.   15.4  54.9 144. ]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 12.0
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 54.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.9   6.3  11.   23.7  56.6 125. ]
# 0
# 3
# 2.9
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 11.0
# got it
# 12
# 30
# 23.7
# got it
# 30
# 70
# 56.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    3.9   7.6  12.9  54.7 125. ]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 7.6
# got it
# 12
# 30
# 12.9
# got it
# 30
# 70
# 54.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   3.4   8.1  15.9  32.7 124.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.9
# got it
# 30
# 70
# 32.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   3.4  12.   15.9  16.4 103.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 12.0
# got it
# 12
# 30
# 15.9
# got it
# 30
# 70
# 16.4
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    3.7  11.2  15.9  54.7 103.8]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 11.2
# got it
# 12
# 30
# 15.9
# got it
# 30
# 70
# 54.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.   3.9  6.8 16.6 56.6 75.4]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 6.8
# 12
# 30
# 16.6
# got it
# 30
# 70
# 56.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.5   5.9   8.1  15.4  56.6 103.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 15.4
# got it
# 30
# 70
# 56.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.    3.7  10.3  16.1  47.4 104. ]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 16.1
# got it
# 30
# 70
# 47.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   4.6  10.7  10.   47.6 124.5]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 4.6
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 10.0
# 30
# 70
# 47.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.5   5.6  12.7  15.6  53.2 151.9]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 12.7
# 12
# 30
# 15.6
# got it
# 30
# 70
# 53.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.6   7.6  10.3  26.6 109.9]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 7.6
# got it
# 12
# 30
# 10.3
# 30
# 70
# 26.6
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5']
# [  1.    1.    1.    1.2   3.7   9.8  12.7  29.3 127.9]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 12.7
# got it
# 30
# 70
# 29.3
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    1.7   5.9  12.2  26.4 110.1]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 1.7
# 7
# 12
# 5.9
# 12
# 30
# 12.2
# got it
# 30
# 70
# 26.4
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.2   3.9   5.9  12.7  24.2  56.9 132.8]
# 0
# 3
# 3.9
# 3
# 7
# 5.9
# got it
# 7
# 12
# 12.7
# 12
# 30
# 24.2
# got it
# 30
# 70
# 56.9
# got it
# ['EMD1', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   3.9  10.5  16.1  38.3 104. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 16.1
# got it
# 30
# 70
# 38.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    5.9  10.7  13.2  43.7 104. ]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 13.2
# got it
# 30
# 70
# 43.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.9  10.5  12.5  42.2 127.9]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 12.5
# got it
# 30
# 70
# 42.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.6  10.3  12.9  26.6 140.6]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 12.9
# got it
# 30
# 70
# 26.6
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    2.    6.1  11.5   9.   53.5 109.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 11.5
# got it
# 12
# 30
# 9.0
# 30
# 70
# 53.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.    2.    5.4   9.8  21.   54.2 127.7]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 21.0
# got it
# 30
# 70
# 54.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.2  3.7  8.1 12.7 38.1 94. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 12.7
# got it
# 30
# 70
# 38.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.2   5.9  10.7  15.6  47.4 104. ]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 15.6
# got it
# 30
# 70
# 47.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.9  10.5  12.5  47.6 122.6]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 12.5
# got it
# 30
# 70
# 47.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   3.7  10.5  11.7  24.7 123.3]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 11.7
# 30
# 70
# 24.7
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5']
# [  1.    1.    1.    2.    3.9  10.3  19.3  42.5 127. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 19.3
# got it
# 30
# 70
# 42.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   3.9  10.7  20.   63.2 109.9]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 20.0
# got it
# 30
# 70
# 63.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    5.6  12.5  21.2  34.7 101.1]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 12.5
# 12
# 30
# 21.2
# got it
# 30
# 70
# 34.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.9  10.3  15.9  47.9 122.6]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 15.9
# got it
# 30
# 70
# 47.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.6  10.7  13.4  30.5 123.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 13.4
# got it
# 30
# 70
# 30.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.    3.7   7.8  11.5  29.8 140.6]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 11.5
# 30
# 70
# 29.8
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5']
# [  1.    1.    1.    1.    1.2   3.2  11.   19.5  42.7 126.5]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 11.0
# got it
# 12
# 30
# 19.5
# got it
# 30
# 70
# 42.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   6.1  10.3  25.4  63.7 109.9]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 25.4
# got it
# 30
# 70
# 63.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.   2.   5.9 11.2 24.9 41.  95.2]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 11.2
# got it
# 12
# 30
# 24.9
# got it
# 30
# 70
# 41.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   3.4   9.3  11.2  42.2 123.8]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 11.2
# 30
# 70
# 42.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.    5.6   7.8  25.1  64.9 113.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 25.1
# got it
# 30
# 70
# 64.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   3.9   6.1  21.   72.  133.5]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 6.1
# 12
# 30
# 21.0
# got it
# 30
# 70
# 72.0
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    2.7   7.3  17.6  18.8  63.2 127.7]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 7.3
# 7
# 12
# 17.6
# 12
# 30
# 18.8
# got it
# 30
# 70
# 63.2
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.7   5.9  12.7  19.   51.3 121.6]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 12.7
# 12
# 30
# 19.0
# got it
# 30
# 70
# 51.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    0.7   1.5   4.2   6.3  22.2  35.4 138.2]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 6.3
# 12
# 30
# 22.2
# got it
# 30
# 70
# 35.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.7   6.3  11.5  29.1  40.5 123.3]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 11.5
# got it
# 12
# 30
# 29.1
# got it
# 30
# 70
# 40.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   3.4   6.1  20.8  26.6 104. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 6.1
# 12
# 30
# 20.8
# got it
# 30
# 70
# 26.6
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    2.    3.7   9.5  24.9  57.4 127.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 24.9
# got it
# 30
# 70
# 57.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    3.4   7.6  18.8  62.7 131.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 7.6
# got it
# 12
# 30
# 18.8
# got it
# 30
# 70
# 62.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.9  10.3  26.1  63.  127.7]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 26.1
# got it
# 30
# 70
# 63.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.2   6.1  12.   19.   35.6 121.8]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 12.0
# got it
# 12
# 30
# 19.0
# got it
# 30
# 70
# 35.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.4   4.2   7.1  24.9  57.1 129.9]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 7.1
# got it
# 12
# 30
# 24.9
# got it
# 30
# 70
# 57.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   3.7   8.3  24.7  57.4 127.4]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 24.7
# got it
# 30
# 70
# 57.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.2   4.2   6.3  23.4  47.1 137.7]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 6.3
# 12
# 30
# 23.4
# got it
# 30
# 70
# 47.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.2   3.7   6.6  28.3  75.  127.4]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 6.6
# 12
# 30
# 28.3
# got it
# 30
# 70
# 75.0
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    1.7   4.2   9.8  27.1  58.8 132.3]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 27.1
# got it
# 30
# 70
# 58.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   4.4   6.1  28.8  57.4 151.1]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.4
# got it
# 7
# 12
# 6.1
# 12
# 30
# 28.8
# got it
# 30
# 70
# 57.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    7.1   8.5  33.4  70.1 131.1]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 7.1
# 7
# 12
# 8.5
# got it
# 12
# 30
# 33.4
# 30
# 70
# 70.1
# ['EMD1*', 'EMD2', 'EMD3*', 'EMD4', 'EMD5']
# [  1.    1.    1.    1.7   3.9   7.1  24.9  50.  149.9]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 7.1
# got it
# 12
# 30
# 24.9
# got it
# 30
# 70
# 50.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   2.4  6.6 15.1 24.9 47.4 92. ]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 6.6
# got it
# 7
# 12
# 15.1
# 12
# 30
# 24.9
# got it
# 30
# 70
# 47.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.4   6.1   8.3  26.4  57.4 129.6]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 26.4
# got it
# 30
# 70
# 57.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    6.1   5.1  29.5  56.2 106.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 5.1
# 12
# 30
# 29.5
# got it
# 30
# 70
# 56.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.1   7.3  22.9  48.8 105. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 7.3
# got it
# 12
# 30
# 22.9
# got it
# 30
# 70
# 48.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.2   5.4   6.1  22.7  55.9 126.2]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.1
# 12
# 30
# 22.7
# got it
# 30
# 70
# 55.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   5.4   5.6  14.6  54.2 105. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 5.6
# 12
# 30
# 14.6
# got it
# 30
# 70
# 54.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   3.4   5.9  23.7  27.6 148.4]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 5.9
# 12
# 30
# 23.7
# got it
# 30
# 70
# 27.6
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [ 1.   1.   1.   2.   5.6  8.5 27.6 40.8 74.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 27.6
# got it
# 30
# 70
# 40.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   2.   6.1  8.3 24.7 47.6 89.1]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 24.7
# got it
# 30
# 70
# 47.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   2.   5.4  6.3 21.5 46.4 90.1]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.3
# 12
# 30
# 21.5
# got it
# 30
# 70
# 46.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    5.4   5.6  23.7  29.1 148.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 5.6
# 12
# 30
# 23.7
# got it
# 30
# 70
# 29.1
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    2.    5.9  13.4  17.3  23.9 113.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 13.4
# 12
# 30
# 17.3
# got it
# 30
# 70
# 23.9
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [ 1.   1.   1.   1.7  5.9 10.  26.1 36.1 95.2]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.0
# got it
# 12
# 30
# 26.1
# got it
# 30
# 70
# 36.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    6.1   8.5  29.3  35.2 131.6]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 29.3
# got it
# 30
# 70
# 35.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.7  3.9  8.3 24.2 56.6 93.5]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 24.2
# got it
# 30
# 70
# 56.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   6.1  10.3  27.3  63.2 134. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 27.3
# got it
# 30
# 70
# 63.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.9   8.5  24.2  52.5 132.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 24.2
# got it
# 30
# 70
# 52.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   2.2   5.6  10.5  26.6  41.3 112.8]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 26.6
# got it
# 30
# 70
# 41.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.6   5.6  23.7  54.4 113.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 5.6
# 12
# 30
# 23.7
# got it
# 30
# 70
# 54.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   2.2  5.1  8.5 27.8 63.  96.4]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 27.8
# got it
# 30
# 70
# 63.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.7  4.6  7.1 23.9 57.1 88.6]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.6
# got it
# 7
# 12
# 7.1
# got it
# 12
# 30
# 23.9
# got it
# 30
# 70
# 57.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    6.3  11.2  26.1  49.6 122.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 11.2
# got it
# 12
# 30
# 26.1
# got it
# 30
# 70
# 49.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    5.9   6.1  26.6  41.3 148.4]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 6.1
# 12
# 30
# 26.6
# got it
# 30
# 70
# 41.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   4.9   8.3  23.7  52.2 128.9]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 23.7
# got it
# 30
# 70
# 52.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.6   6.1  26.6  74.  148.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 6.1
# 12
# 30
# 26.6
# got it
# 30
# 70
# 74.0
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    1.5   5.4   6.6  24.2  74.  148.2]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.6
# 12
# 30
# 24.2
# got it
# 30
# 70
# 74.0
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   5.6   5.6  23.4  74.  154.1]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 5.6
# 12
# 30
# 23.4
# got it
# 30
# 70
# 74.0
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.7   5.4   6.1  23.2  64.2 145.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.1
# 12
# 30
# 23.2
# got it
# 30
# 70
# 64.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.6  10.   17.6  48.6 131.6]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 10.0
# got it
# 12
# 30
# 17.6
# got it
# 30
# 70
# 48.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   5.1   8.5  28.1  49.1 142.3]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 28.1
# got it
# 30
# 70
# 49.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.4   8.3  33.   66.2 143.3]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 33.0
# 30
# 70
# 66.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    3.2   5.9   8.8  27.8  73.7 137.9]
# 0
# 3
# 3.2
# 3
# 7
# 5.9
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 27.8
# got it
# 30
# 70
# 73.7
# ['EMD1', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.2   2.2   7.1  11.   23.4  74.  153.8]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 7.1
# 7
# 12
# 11.0
# got it
# 12
# 30
# 23.4
# got it
# 30
# 70
# 74.0
# ['EMD1*', 'EMD2', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   5.1   9.5  22.7  27.8 144. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 22.7
# got it
# 30
# 70
# 27.8
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.7   4.9   8.5  26.4  67.1 154.1]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 26.4
# got it
# 30
# 70
# 67.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   2.    5.1   8.3  23.2  67.1 124.8]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 23.2
# got it
# 30
# 70
# 67.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   1.7   4.9   8.8  22.9  71.3 156.7]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 22.9
# got it
# 30
# 70
# 71.3
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.2   2.    4.9   8.5  27.6  65.9 154.1]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 27.6
# got it
# 30
# 70
# 65.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   5.1   9.3  12.   64.5 127.2]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 12.0
# 30
# 70
# 64.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.    1.7   3.9   8.1  27.3  67.1 153.3]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.9
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 27.3
# got it
# 30
# 70
# 67.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   2.2   5.4   8.3  16.4  48.3 111.6]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 16.4
# got it
# 30
# 70
# 48.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   4.6   8.5  11.   66.7 127.2]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 4.6
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 11.0
# 30
# 70
# 66.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.    4.9   8.8  10.7  64.5 127. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 10.7
# 30
# 70
# 64.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.7   4.9   8.3  15.6  45.7 126.7]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 4.9
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 15.6
# got it
# 30
# 70
# 45.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   5.4   8.1   9.3  51.  126.7]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 8.1
# got it
# 12
# 30
# 9.3
# 30
# 70
# 51.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.7   5.4   9.3  22.9  49.8 127. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 22.9
# got it
# 30
# 70
# 49.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   3.4   9.8  10.7  31.5 127. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 10.7
# 30
# 70
# 31.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.5   5.6   7.8  19.3  37.8 126.5]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 19.3
# got it
# 30
# 70
# 37.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.7   5.9   9.3  16.1  48.3 122.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 16.1
# got it
# 30
# 70
# 48.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.1   9.   20.   44.9 114. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 9.0
# got it
# 12
# 30
# 20.0
# got it
# 30
# 70
# 44.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.1   8.8  14.9  48.8 126.7]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 14.9
# got it
# 30
# 70
# 48.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   1.7   8.3   8.5  48.1 126.7]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 1.7
# 7
# 12
# 8.3
# got it
# 12
# 30
# 8.5
# 30
# 70
# 48.1
# got it
# ['EMD1*', 'EMD2', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.2   4.6   9.3  11.2  19.5 126.7]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 4.6
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 11.2
# 30
# 70
# 19.5
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5']
# [  1.    1.    1.    1.5   4.2   9.5  12.   50.  126.5]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 4.2
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 12.0
# 30
# 70
# 50.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.7   5.6   9.5  12.2  37.6 131.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 12.2
# got it
# 30
# 70
# 37.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.4   6.8  16.4  18.1 123. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.8
# 12
# 30
# 16.4
# got it
# 30
# 70
# 18.1
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    2.    5.1   9.3  23.2  50.5 116.7]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.1
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 23.2
# got it
# 30
# 70
# 50.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.5   6.6   9.5  20.   50.3 126.5]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 6.6
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 20.0
# got it
# 30
# 70
# 50.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   4.4   9.3  11.   46.9 126.5]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 4.4
# got it
# 7
# 12
# 9.3
# got it
# 12
# 30
# 11.0
# 30
# 70
# 46.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    2.    5.4   9.5  11.5  47.9 126.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 11.5
# 30
# 70
# 47.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.5   6.3   7.1  13.4  37.4 122.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 7.1
# got it
# 12
# 30
# 13.4
# got it
# 30
# 70
# 37.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.   1.2  6.6  9.5 17.1 49.8 94.7]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.6
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 17.1
# got it
# 30
# 70
# 49.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.5  6.1  9.5 12.7 50.  94.7]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 12.7
# got it
# 30
# 70
# 50.0
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.2  3.4  9.5 12.5 47.4 94.7]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.4
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 12.5
# got it
# 30
# 70
# 47.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.2   3.2   6.3   9.5  54.7 123. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 6.3
# 12
# 30
# 9.5
# 30
# 70
# 54.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.5   2.9   6.8   9.8  37.6 123. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 2.9
# 7
# 12
# 6.8
# 12
# 30
# 9.8
# 30
# 70
# 37.6
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4', 'EMD5*']
# [ 1.   1.   1.   1.2  6.3  9.8 17.3 49.8 94.7]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 17.3
# got it
# 30
# 70
# 49.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.   1.   6.3  9.8 14.6 55.9 94.7]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 14.6
# got it
# 30
# 70
# 55.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   6.1   9.8  15.9  55.4 123. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 15.9
# got it
# 30
# 70
# 55.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   3.2   6.6  15.1  55.4 123. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 6.6
# 12
# 30
# 15.1
# got it
# 30
# 70
# 55.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.4   6.3   9.8  19.   57.1 123. ]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 19.0
# got it
# 30
# 70
# 57.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    5.6   6.8  16.6  27.1 112.8]
# 0
# 3
# 1.0
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 6.8
# 12
# 30
# 16.6
# got it
# 30
# 70
# 27.1
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.2   3.7   6.6  16.8  24.7 144.3]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 3.7
# got it
# 7
# 12
# 6.6
# 12
# 30
# 16.8
# got it
# 30
# 70
# 24.7
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    2.    6.1   6.3  23.2  24.4 122.1]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 6.3
# 12
# 30
# 23.2
# got it
# 30
# 70
# 24.4
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.2   6.3   9.8  27.1  57.1 123. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 27.1
# got it
# 30
# 70
# 57.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   6.1   9.8  19.   57.6 122.8]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 19.0
# got it
# 30
# 70
# 57.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   2.4   6.1   9.8  55.2 123. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 2.4
# 7
# 12
# 6.1
# 12
# 30
# 9.8
# 30
# 70
# 55.2
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4', 'EMD5*']
# [  1.    1.    1.2   2.9   6.6  12.9  55.2 123. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 2.9
# 7
# 12
# 6.6
# 12
# 30
# 12.9
# got it
# 30
# 70
# 55.2
# got it
# ['EMD1*', 'EMD2', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   5.4   6.8  16.8  32.5 122.8]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.8
# 12
# 30
# 16.8
# got it
# 30
# 70
# 32.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   5.4   6.6  16.8  27.3 144.5]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.6
# 12
# 30
# 16.8
# got it
# 30
# 70
# 27.3
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.    1.7   6.1  10.7  17.3  74.  144.5]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 17.3
# got it
# 30
# 70
# 74.0
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.2   6.3   9.8  27.1  56.6 116. ]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.8
# got it
# 12
# 30
# 27.1
# got it
# 30
# 70
# 56.6
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.5  5.6 10.  23.4 55.2 97.7]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 10.0
# got it
# 12
# 30
# 23.4
# got it
# 30
# 70
# 55.2
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.7   1.5   8.5  12.9  55.2 124.3]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 1.5
# 7
# 12
# 8.5
# got it
# 12
# 30
# 12.9
# got it
# 30
# 70
# 55.2
# got it
# ['EMD1*', 'EMD2', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.2   5.9   6.8  16.8  26.6 124.3]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 6.8
# 12
# 30
# 16.8
# got it
# 30
# 70
# 26.6
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    1.5   3.2   6.8  10.5  50.8 145.5]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 6.8
# 12
# 30
# 10.5
# 30
# 70
# 50.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.2   2.9   6.1  10.5  17.3  57.9 144.5]
# 0
# 3
# 2.9
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 17.3
# got it
# 30
# 70
# 57.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.2   1.7   6.3  10.7  27.1  50.5 116. ]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 27.1
# got it
# 30
# 70
# 50.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.2   2.7   6.1   8.3  23.7  54.9 124.5]
# 0
# 3
# 2.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 23.7
# got it
# 30
# 70
# 54.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    6.3   8.3  16.6  46.4 124.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 8.3
# got it
# 12
# 30
# 16.6
# got it
# 30
# 70
# 46.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.2  6.1  6.3 16.8 50.5 96.9]
# 0
# 3
# 1.2
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 6.3
# 12
# 30
# 16.8
# got it
# 30
# 70
# 50.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.2   6.1  10.5  23.4  69.3 122.3]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 23.4
# got it
# 30
# 70
# 69.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.2   5.9   8.5  26.1  54.4 123.8]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 8.5
# got it
# 12
# 30
# 26.1
# got it
# 30
# 70
# 54.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.7  3.2  6.3 23.4 51.3 96.7]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 6.3
# 12
# 30
# 23.4
# got it
# 30
# 70
# 51.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.   1.   2.2  6.3  6.6 17.1 45.9 96.9]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 6.6
# 12
# 30
# 17.1
# got it
# 30
# 70
# 45.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.9   6.1   8.8  24.9  48.3 128.7]
# 0
# 3
# 2.9
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 24.9
# got it
# 30
# 70
# 48.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    6.3   9.5  17.3  61.8 129.9]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 17.3
# got it
# 30
# 70
# 61.8
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   2.2   6.1  10.5  23.2  68.1 131.6]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.5
# got it
# 12
# 30
# 23.2
# got it
# 30
# 70
# 68.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    1.7   6.1  10.   23.2  65.9 131.8]
# 0
# 3
# 1.7
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 10.0
# got it
# 12
# 30
# 23.2
# got it
# 30
# 70
# 65.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.4   6.1  22.9  48.1 131.6]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.1
# 12
# 30
# 22.9
# got it
# 30
# 70
# 48.1
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [ 1.   1.   1.2  2.9  6.3  8.8 26.9 51.5 96.7]
# 0
# 3
# 2.9
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 26.9
# got it
# 30
# 70
# 51.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    6.1   8.8  26.1  47.4 103.5]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 26.1
# got it
# 30
# 70
# 47.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.5   3.2   6.3  12.9  34.4  63.7 110.8]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 6.3
# 12
# 30
# 12.9
# got it
# 30
# 70
# 34.4
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.2   2.2   6.3   9.5  23.2  65.9 131.6]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 9.5
# got it
# 12
# 30
# 23.2
# got it
# 30
# 70
# 65.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.    5.9  10.3  22.7  66.7 131.6]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 22.7
# got it
# 30
# 70
# 66.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    5.4  10.3  22.9  47.9 131.6]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 10.3
# got it
# 12
# 30
# 22.9
# got it
# 30
# 70
# 47.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.2   2.4   5.6   8.8  26.6  51.5 103.3]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 5.6
# got it
# 7
# 12
# 8.8
# got it
# 12
# 30
# 26.6
# got it
# 30
# 70
# 51.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   2.    5.4   6.3  13.4  53.7 123. ]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.3
# 12
# 30
# 13.4
# got it
# 30
# 70
# 53.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.5   2.4   6.1   6.3  25.6  71.  132.8]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 6.1
# got it
# 7
# 12
# 6.3
# 12
# 30
# 25.6
# got it
# 30
# 70
# 71.0
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5']
# [  1.    1.    1.    2.4   5.4   6.6  23.7  56.9 142.3]
# 0
# 3
# 2.4
# got it
# 3
# 7
# 5.4
# got it
# 7
# 12
# 6.6
# 12
# 30
# 23.7
# got it
# 30
# 70
# 56.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.    2.2   5.9  10.7  31.7  56.9 124. ]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 5.9
# got it
# 7
# 12
# 10.7
# got it
# 12
# 30
# 31.7
# 30
# 70
# 56.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4', 'EMD5*']
# [  1.    1.    1.    1.5   3.2   6.6  23.7  53.7 123. ]
# 0
# 3
# 1.5
# got it
# 3
# 7
# 3.2
# got it
# 7
# 12
# 6.6
# 12
# 30
# 23.7
# got it
# 30
# 70
# 53.7
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.    4.4   7.8  26.9  53.5 123.3]
# 0
# 3
# 2.0
# got it
# 3
# 7
# 4.4
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 26.9
# got it
# 30
# 70
# 53.5
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    2.2   6.3   7.8  26.6  69.3 142.1]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 7.8
# got it
# 12
# 30
# 26.6
# got it
# 30
# 70
# 69.3
# got it
# ['EMD1*', 'EMD2*', 'EMD3*', 'EMD4*', 'EMD5*']
# [  1.    1.    1.    1.2   2.2   6.3   6.1  26.4  56.9 142.3]
# 0
# 3
# 2.2
# got it
# 3
# 7
# 6.3
# got it
# 7
# 12
# 6.1
# 12
# 30
# 26.4
# got it
# 30
# 70
# 56.9
# got it
# ['EMD1*', 'EMD2*', 'EMD3', 'EMD4*', 'EMD5*']

# %%
scores

# %%
[f, t] = pyACA.computePitch('TimeAcf', eIMFs[3], 1000, afWindow=None, iBlockLength=512, iHopLength=256)
plt.plot(np.squeeze(f))

# %%
peaks_EMD = []
for e in range(len(eIMFs[1 :-2])):
    freqs, psd = scipy.signal.welch(eIMFs[e], 1000, nfft = 4096, nperseg = 1024)
    index, value = max(enumerate(psd), key=operator.itemgetter(1))
    peaks_EMD.append(freqs[index])
    
peaks_EMD = np.round(peaks_EMD[1:-1], 1)
np.flip(peaks_EMD)

# %%
eIMFs[3] = np.interp(eIMFs[3], (eIMFs[3].min(), eIMFs[3].max()), (-1, 1))

# %%
eIMFs.shape
IMF0 = eIMFs[0][0:6000]
IMF1 = eIMFs[1][0:6000]
IMF2 = eIMFs[2][0:6000]
IMF3 = eIMFs[3][0:6000]
IMF4 = eIMFs[4][0:6000]
IMF5 = eIMFs[5][0:6000]
IMF6 = eIMFs[6][0:6000]
IMF7 = eIMFs[7][0:6000]
IMF8 = eIMFs[8][0:6000]
#IMF9 = eIMFs[9][0:6000]
